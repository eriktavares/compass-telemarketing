# %% [markdown]
# # Analise de Dados Serviço de Telemarquete

# %% [markdown]
# Cenário:
#
# “Você provavelmente já recebeu uma ligação de telemarketing oferecendo um produto que você não precisa. Essa situação de estresse é minimizada quando você oferece um produto que o cliente realmente precisa.”

# %% [markdown]
# # Leitura dos dados

# %%
import pandas as pd
df_metadata= pd.read_csv('../Data/data-challenge/metadata.csv')
df_train= pd.read_csv('../Data/data-challenge/train.csv'

# %% [markdown]
# # Metadata

# %% [markdown]
# O metadata tem a descrição do tipo da variável, Quantitativa ou Qualidativa. Abaixo pode ser visto as quantidades de cada tipo
# de váriavel.
#
#
# As variáveis quantitativas ou numéricas podem ser
#
# Discretas: assumem apenas valores inteiros. Ex.: número de irmãos, número de passageiros
#
# Contínuas: assume qualquer valor no intervalo dos números reais. Ex.: peso, altura
# As variáveis qualitativas ou categóricas podem ser
#
# Nominais: quando as categorias não possuem uma ordem natural. Ex.: nomes, cores, sexo.
#
# Ordinais: quando as categorias podem ser ordenadas. Ex.: tamanho (pequeno, médio, grande), classe social (baixa, média, alta), grau de instrução (básico, médio, graduação, pós-graduaçã
#
# [https://www.inf.ufsc.br/~andre.zibetti/probabilidade/aed.html]

# %%
df_metadata.head()
# Out:
#   Variavel cod        Variavel tipo
# 0           id  Qualitativo nominal
# 1         var1  Qualitativo nominal
# 2         var2  Qualitativo nominal
# 3         var3  Qualitativo nominal
# 4         var4  Qualitativo nominal

# %% [markdown]
# Quantidade de cada tipo de váriável

# %%
df_metadata['Variavel tipo'].value_counts()
# Out:
# Qualitativo nominal      36
# Quantitativo discreto    18
# Quantitativo continua    12
# Qualitativo ordinal       4
# Name: Variavel tipo, dtype: int64

# %% [markdown]
# # Train

# %% [markdown]
# No dados contidos no arquivo train, estão os valores das variáveis e o valor da váriável alvo y, com o inderesse do cliente.

# %%
df_train.head()
# Out:
#    id  var1  var2  var3   var4  var5  var6  var7  var8  var9  ...       var60  \
# 0   1    18    19  2853  29442  1386  2435    35  -999     3  ...    0.311441
# 1   8     4   110  1986  13684  7189  -999  -999    17     3  ... -999.000000
# 2  30     0    39  1019  10232   678   791    16  -999     3  ... -999.000000
# 3  43    20    39  1751   2689  8235  1042    13    10     1  ... -999.000000
# 4  46     7    44  2262  29428  6031   304    16  -999     3  ...    0.021226
#
#         var61     var62     var63     var64       var65      var66     var67  \
# 0    0.142303  0.056146  0.632694  0.024054    0.253356    0.00603  0.132353
# 1 -999.000000  0.070991  0.773966  0.019315 -999.000000 -999.00000  0.147059
# 2    0.200814  0.051046  0.980827  0.018536 -999.000000 -999.00000  0.382353
# 3    0.352379  0.044301  0.951564  0.023684    0.363370    0.00201  0.147059
# 4    0.226161  0.059125  0.906155  0.020733 -999.000000 -999.00000  0.455882
#
#       var68  y
# 0  0.139706  1
# 1  0.106618  0
# 2  0.242647  0
# 3  0.132353  0
# 4  0.132353  1
#
# [5 rows x 70 columns]

# %%
df_train= df_train.drop(columns=['id'])

# %%
df_train.shape
# Out:
# (14123, 69)

# %% [markdown]
# Como o quantidade de dados 1 em y é bem menor do que 0, podemos assumir que o inderesse do cliente é na ocorrência 1 e o não interesse em 0. Pela própria descrição do problema, sabemos que há menos casos de interesse do cliente, e esse o objetivo da analise.

# %%
target_col = 'y'
target=df_train[target_col]
df_vars= df_train.drop(columns=[target_col])
df_train[target_col].value_counts()
# Out:
# 0    11273
# 1     2850
# Name: y, dtype: int64

# %%
dict_target = { 0: 'Não Precisa', 
               1: 'Precisa'}

# %% [markdown]
# Na tabela abaixo pode ser visto que em 20% dos casos, o cliente precisa do produto, e 80% não precisa. Claramente é possível já imaginar que, ligando para esses 20% que precisam a possibilidade de fechar a venda é maior, ou "quase certa", porque está direcionado a um cliente que precisa do produto, economiza tempo do vendedor e aumenta a acertividade.

# %%
dist_quantidades = pd.DataFrame({'frequencia' : df_train[target_col].value_counts(), 
                                      'Porcentagem (%)': df_train[target_col].value_counts(normalize=1) *100})
dist_quantidades.rename(index=dict_target, inplace = True)
dist_quantidades.rename_axis(target_col, axis='columns', inplace=True)
dist_quantidades
# Out:
# y            frequencia  Porcentagem (%)
# Não Precisa       11273        79.820152
# Precisa            2850        20.179848

# %%
import matplotlib.pyplot as plt
fig = plt.figure( figsize =(5,4))
ax = fig.add_axes([0,0,1,1])
types= ['Não Precisa', 'Precisa']
percent=[pd.DataFrame(target).value_counts(normalize=True)[1],pd.DataFrame(target).value_counts(normalize=True)[0]]
ax.bar(types,percent)
ax.set_ylabel('Diagnosticos')
ax.set_xlabel('Percentual')
for index, value in enumerate(percent):
        txt= f'{round(value*100, 2)} %'
        y_coord = value + 0.005
        x_coord=index - 0.1
        ax.text(x=x_coord,y=y_coord, s=txt, fontsize=12)
        ax.grid()
        
plt.show()

# %% [markdown]
# Mas a pergunta é como vamos descobrir se o cliente esta precisando ou não do produto. O entendimento das variáveis do dataset e como elas se relacionam com a necessidade ou não do cliente.

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# # Dados Nulos

# %% [markdown]
# Acima já fizemos uma pequena visualização dos dados com a verificação do tipo da váriável, Quantitativa ou qualitativa. Agora vamos verificar se algum dado está faltante ou nulo. Para isso, uma verificação se é nulo, e uma soma de todos os resultados de cada váriável, inclusive a variável alvo.

# %%
verificação_nulos=df_train.isnull().sum()
df_train.isnull().sum()
# Out:
# var1     0
# var2     0
# var3     0
# var4     0
# var5     0
#         ..
# var65    0
# var66    0
# var67    0
# var68    0
# y        0
# Length: 69, dtype: int64

# %%
verificação_nulos.sum()
# Out:
# 0

# %% [markdown]
# É interessante ver também a tipagem de cada variável, do dataset. Podemos ver que são int64 e float64. O dataset possívelmente
# já possue um tratamento previo, caso fosse houve outros tipos, como string, poderia ser utilizando algoritmo e transformação.

# %% [markdown]
# # Tipos das variáveis

# %%
df_train.dtypes.value_counts()
# Out:
# int64      55
# float64    14
# dtype: int64

# %% [markdown]
# # Correlação

# %% [markdown]
# Esse dataset possui um número grande de variaveis, pode ser verificado a correlação entre elas para verificar uma possível redução de dimensionalidade.
#
# Coeficientes de Correlação:
#
# ρ = 0,9 a 1 (positivo ou negativo): correlação muito forte;
#
# ρ = 0,7 a 09 (positivo ou negativo): correlação forte;
#
# ρ = 0,5 a 0,7 (positivo ou negativo): correlação moderada;
#
# ρ = 0,3 a 0,5 (positivo ou negativo): correlação fraca;
#
# ρ = 0 a 0,3 (positivo ou negativo): não possui correlação.

# %%
import numpy as np
import seaborn as sns

correlationMatriz= df_vars.corr()
plt.figure(figsize = (25, 25))

sns.heatmap(correlationMatriz, annot = True, fmt = ".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Como existem muitas váriáveis a visualização fica até um pouco complicada. Porém é possível notar que as variáveis var56 e var57
# possuem o mesmo resultado de correlação, assim como var9 e var52, var26 e var58, 56 e 57, e var65 e 66. Será feito a remoção de 4 colunas, uma para cada par.

# %%
correlationMatriz2 = correlationMatriz[correlationMatriz>0.99]
correlationMatriz2  = correlationMatriz2 .sum()
correlationMax = correlationMatriz2[correlationMatriz2>1]
correlationMax.sort_values(ascending=True)
# Out:
# var9     1.999162
# var52    1.999162
# var56    1.999289
# var57    1.999289
# var26    1.999968
# var58    1.999968
# var65    2.000000
# var66    2.000000
# var18    3.993550
# var15    3.995397
# var16    3.995536
# var17    3.996738
# dtype: float64

# %%
df_vars_t1=df_vars.drop(columns=["var52","var57","var58", "var66"])

# %% [markdown]
# # Boxplot

# %% [markdown]
# Em estatística descritiva, diagrama de caixa, diagrama de extremos e quartis, boxplot ou box plot é uma ferramenta gráfica para representar a variação de dados observados de uma variável numérica por meio de quartis (ver figura 1, onde o eixo horizontal representa a variável) https://pt.wikipedia.org/wiki/Diagrama_de_caixa

# %% [markdown]
# ![unnamed-chunk-1-1.png](attachment:unnamed-chunk-1-1.png)

# %% [markdown]
# No boxplot abaixo, é possível ver que existe uma diferença de escala entre os dados, e também pode ser visto que pode haver alguns outliers
# ou dados que estão um pouco fora do padrão dos demais.

# %%
fig = plt.figure(figsize =(20, 10))
# Creating plot
df_vars_t1.boxplot()
plt.xticks(rotation = 90)
# show plot
plt.show()

# %%
ot=df_vars_t1['var7']<0
ot.value_counts()
# Out:
# False    12228
# True      1895
# Name: var7, dtype: int64

# %%
df_vars_t1
# Out:
#        var1  var2  var3   var4  var5  var6  var7  var8  var9  var10  ...  \
# 0        18    19  2853  29442  1386  2435    35  -999     3     63  ...
# 1         4   110  1986  13684  7189  -999  -999    17     3     63  ...
# 2         0    39  1019  10232   678   791    16  -999     3     63  ...
# 3        20    39  1751   2689  8235  1042    13    10     1     14  ...
# 4         7    44  2262  29428  6031   304    16  -999     3     63  ...
# ...     ...   ...   ...    ...   ...   ...   ...   ...   ...    ...  ...
# 14118     4    39  2511  28766  1109  2094    31    24     3   -999  ...
# 14119    19   129  1114   -999  6376  -999  -999    27  -999   -999  ...
# 14120    27    44  1786  23761  9048   623    35    27     3     14  ...
# 14121     4    89   210  19593  3634  2453    35    27     1     63  ...
# 14122    21    53   568   4612  4982  1438    33    25     3     63  ...
#
#          var56       var59       var60       var61     var62     var63  \
# 0        0.137    0.058070    0.311441    0.142303  0.056146  0.632694
# 1        0.308    0.248909 -999.000000 -999.000000  0.070991  0.773966
# 2        0.213    0.214520 -999.000000    0.200814  0.051046  0.980827
# 3        0.716    0.349421 -999.000000    0.352379  0.044301  0.951564
# 4        0.596    0.189641    0.021226    0.226161  0.059125  0.906155
# ...        ...         ...         ...         ...       ...       ...
# 14118    0.048    0.122448 -999.000000    0.069347  0.036178  0.869828
# 14119 -999.000 -999.000000 -999.000000    0.295418  0.055899  0.921292
# 14120    0.029    0.207001 -999.000000    0.203394  0.040697  0.930373
# 14121    0.154    0.200405    0.070788    0.381038  0.100384  0.680121
# 14122    0.554    0.256477 -999.000000    0.229701  0.125199  0.877901
#
#           var64       var65     var67     var68
# 0      0.024054    0.253356  0.132353  0.139706
# 1      0.019315 -999.000000  0.147059  0.106618
# 2      0.018536 -999.000000  0.382353  0.242647
# 3      0.023684    0.363370  0.147059  0.132353
# 4      0.020733 -999.000000  0.455882  0.132353
# ...         ...         ...       ...       ...
# 14118  0.016160 -999.000000  0.455882  0.147059
# 14119  0.018293 -999.000000  0.147059  0.198529
# 14120  0.009440 -999.000000  0.397059  0.158088
# 14121  0.041096 -999.000000  0.264706  0.128676
# 14122  0.046154 -999.000000  0.176471  0.128676
#
# [14123 rows x 64 columns]

# %%
df_vars_t1[df_vars_t1['var2']< 0]
# Out:
#        var1  var2  var3   var4  var5  var6  var7  var8  var9  var10  ...  \
# 5        18  -999  -999  16114   208  -999  -999  -999     1     63  ...
# 7         5  -999  -999  25373  9048  -999  -999  -999     1     63  ...
# 27        5  -999  -999  31070  9957  2277    27  -999     3     63  ...
# 42        5  -999  -999  17512  9383   522    35  -999  -999   -999  ...
# 45       20  -999  -999  29522  5732  2100    35  -999     3     63  ...
# ...     ...   ...   ...    ...   ...   ...   ...   ...   ...    ...  ...
# 13948     4  -999  -999   -999  6376  -999  -999  -999  -999   -999  ...
# 13975    19  -999  -999   9591  1150   304    16  -999     3     63  ...
# 13990     4  -999  -999  21482  3033  1095    35  -999     3     63  ...
# 13991     4  -999  -999   -999  6376  -999  -999  -999  -999   -999  ...
# 14078    19  -999  -999  28525  3341  2391    35  -999     3     63  ...
#
#          var56       var59       var60     var61     var62     var63  \
# 5        0.497 -999.000000    0.057837  0.391608  0.080977  0.897074
# 7        0.213    0.247192 -999.000000  0.703803  0.124198  0.828456
# 27       0.615    0.151504    0.084066  0.178165  0.061636  0.937437
# 42    -999.000 -999.000000 -999.000000  0.290408  0.051290  0.983855
# 45       0.752    0.128349 -999.000000  0.132312  0.048786  0.860747
# ...        ...         ...         ...       ...       ...       ...
# 13948 -999.000 -999.000000 -999.000000  0.426131  0.244059  0.405651
# 13975    0.779    0.160303    0.113798  0.319472  0.093933  0.720484
# 13990    0.061    0.136926    0.041843  0.149192  0.092177  0.885974
# 13991 -999.000 -999.000000 -999.000000  0.210280  0.159494  0.893037
# 14078    0.740    0.128443    0.067250  0.192783  0.082055  0.533804
#
#           var64  var65       var67     var68
# 5      0.019915 -999.0 -999.000000  0.198529
# 7      0.030033 -999.0 -999.000000  0.301471
# 27     0.056540 -999.0 -999.000000  0.209559
# 42     0.014997 -999.0 -999.000000  0.227941
# 45     0.015776 -999.0 -999.000000  0.261029
# ...         ...    ...         ...       ...
# 13948  0.055160 -999.0 -999.000000  0.205882
# 13975  0.044366 -999.0 -999.000000  0.191176
# 13990  0.017603 -999.0    0.323529  0.172794
# 13991  0.037621 -999.0 -999.000000  0.132353
# 14078  0.024297 -999.0 -999.000000  0.246324
#
# [599 rows x 64 columns]

# %%
valor=dados['var2']
Q1=valor.quantile(.25)
Q3=valor.quantile(.75)
IIQ = Q3- Q1
limite_inf= Q1 - 1.5 *IIQ
limite_sup= Q3 - 1.5 *IIQ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15628/2820924153.py in <module>
# ----> 1 valor=dados['var2']
#       2 Q1=valor.quantile(.25)
#       3 Q3=valor.quantile(.75)
#       4 IIQ = Q3- Q1
#       5 limite_inf= Q1 - 1.5 *IIQ
#
# NameError: name 'dados' is not defined

# %% [markdown]
# Uma forma de normalização dos dados é utilizar o sklearn StandardScale
#
# Standardize features by removing the mean and scaling to unit variance.
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer


normalize = PowerTransformer()
df_vars_t2=normalize.fit(df_vars_t1)
df_vars_t2= normalize.transform(df_vars_t1)
df_vars_t2= pd.DataFrame(data =df_vars_t2, columns = df_vars_t1.keys())
df_vars_t2.head()


fig = plt.figure(figsize =(20, 10))
# Creating plot
df_vars_t2.boxplot()
plt.xticks(rotation = 90)
# show plot
plt.show()
